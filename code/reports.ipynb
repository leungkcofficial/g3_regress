# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import gc

gc.collect()
# Out:
# 0

# %%
# Load the existing test_results from a JSON file
with open('/mnt/d/pydatascience/g3_regress/data/results/ann_cluster.json', 'r') as json_file:
    test_results = json.load(json_file)

# %%
test_results
# Out:
# [{'AIC': 6422.258483886719,
#   'concordance_index': 0.9602199559249068,
#   'integrated_brier_score': 0.12761881523509935,
#   'brier_series': [0.019301489029149178,
#    0.06517937154212722,
#    0.14269611274567703,
#    0.24152669358662718,
#    8.88702369566718e-06],
#   'neg_log_likelihood': 0.36941387322181896,
#   'n_a_chi2': [{'Year': 1,
#     'Chi2_Stat': 4750.958744190468,
#     'P_Value': 0.0,
#     'Observed_Events': [0.0, 0.0, 2.3231822705815173, 0.0, 127.53603643755484],
#     'Expected_Events': [13.230130095329201,
#      106.45973685366998,
#      555.9118675833419,
#      1453.8464450263048,
#      1963.753941224395],
#     'Sample_Size': [8103, 8102, 8103, 8102, 8103]},
#    {'Year': 2,
#     'Chi2_Stat': 11733.412844744887,
#     'P_Value': 0.0,
#     'Observed_Events': [0.0, 0.0, 2.3231822705815173, 0.0, 127.51394949342102],
#     'Expected_Events': [27.905407294708322,
#      222.83414566348273,
#      1120.6588194646934,
#      2763.152303331531,
# ...
